# %%
import zarr
zarr_array = zarr.open_array("/home/samee/axle_data/nibib_download/mergedDeconXY_1009.ome.zarr/0/")
print(zarr_array.shape)
# Out:
# (1, 1, 1, 22792, 13023)

# %%
zarr_array_2 = zarr.open_array("/home/samee/axle_data/test_image_3.ome.zarr/0/")
print(zarr_array_2.shape)
# Out:
# (1, 100, 22792, 13023)

# %%
import matplotlib.pyplot as plt
image_data = zarr_array_2[0,9, 11000:11000+2048, 5000:5000+2048]
print(image_data.sum())
# Plot the grayscale image using matplotlib
plt.imshow(image_data, cmap="gray")
plt.axis('off')  # Turn off the axis
plt.title('Grayscale Image')
plt.show()
# Out:
# 429947404

# %%
import matplotlib.pyplot as plt
image_data = zarr_array[0,0,0, 11000:11000+2048, 5000:5000+2048]
print(image_data.sum())
# Plot the grayscale image using matplotlib
plt.imshow(image_data)
plt.axis('off')  # Turn off the axis
plt.title('Grayscale Image')
plt.show()
# Out:
# 429947404
